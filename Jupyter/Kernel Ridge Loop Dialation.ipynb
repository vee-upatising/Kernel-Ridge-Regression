# %%
import numpy as np
import kaggle
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.kernel_ridge import KernelRidge
from sklearn.linear_model import Ridge
import csv

# %%
################################################################
# load housing data
def load_housing_data():
    train_x = np.load('../../Data/Housing/train_x.npy')
    train_y = np.load('../../Data/Housing/train_y.npy')
    test_x = np.load('../../Data/Housing/test_x.npy')
    return train_x, train_y, test_x
################################################################

# %%
################################################################
# Compute MSE
def compute_MSE(y, y_hat):
        # mean squared error
        return np.mean(np.power(y - y_hat, 2))
################################################################

# %%
train_x, train_y, test_x = load_housing_data()

# %%
train_y = train_y.reshape(len(train_y),1)

# %%
data = np.load('synthethic_test.npy')
train_x_new = data[:,:12]
train_y_new = data[:,12:]

# %%
train_y_new = np.load('syn_y.npy')

# %%
kf = KFold(n_splits=5,shuffle=True, random_state=69)
models = []

# %%
parameters = [['rbf',1,0.001],['poly',1,0.001],['linear',1,0.001],['rbf',1,0.01],['poly',1,0.01],['rbf',1,0.1],['poly',1,0.1],['rbf',1,1],['poly',1,1],['rbf',0.1,0.001],['poly',0.1,0.001],['linear',0.1,0.001],['rbf',0.1,0.01],['poly',0.1,0.01],['rbf',0.1,0.1],['poly',0.1,0.1],['rbf',0.1,1],['poly',0.1,1],['rbf',0.01,0.001],['poly',0.01,0.001],['linear',0.01,0.001],['rbf',0.01,0.01],['poly', 0.01,0.01],['rbf', 0.01,0.1],['poly', 0.01,0.1],['rbf', 0.01,1],['poly', 0.01,1],['rbf',0.001,0.001],['poly',0.001,0.001],['linear',0.001,0.001],['rbf',0.001,0.01],['poly', 0.001,0.01],['rbf', 0.001,0.1],['poly', 0.001,0.1],['rbf', 0.001,1],['poly', 0.001,1],['rbf', 0.005,0.001],['poly', 0.005,0.001],['linear', 0.005,0.001],['rbf', 0.005,0.01],['poly', 0.005,0.01],['rbf', 0.005,0.1],['poly', 0.005,0.1],['rbf', 0.005,1],['poly', 0.005,1]]

# %%
for i in range(len(parameters)):
    kernel = KernelRidge(kernel=parameters[i][0],alpha=parameters[i][1],gamma=parameters[i][2])
    accuracy = []
    #K-Fold Cross Validation
    for train_index, test_index in kf.split(train_x_new):
        x_train, x_test = train_x_new[train_index], train_x_new[test_index]
        y_train, y_test = train_y_new[train_index], train_y_new[test_index]
        #Fit model on each fold
        kernel.fit(x_train, y_train)
        #Predict on testing fold
        predict = kernel.predict(x_test)
        predict = predict.reshape(len(predict),1)
        #Accuracy between prediction and true value for each K-Fold Validation
        accuracy.append(compute_MSE(y_test, predict))
    mean = np.average(accuracy)
    if(parameters[i][0] == 'rbf'):
        print("Kernel = " + parameters[i][0] + ", Alpha = " + str(parameters[i][1]) + ", Gamma = " + str(parameters[i][2]))
        print("5-Fold Cross Validation MSE = " + str(mean))
    elif(parameters[i][0] == 'poly'):
        print("Kernel = " + parameters[i][0] + ", Alpha = " + str(parameters[i][1]) + ", Gamma = " + str(parameters[i][2]))
        print("5-Fold Cross Validation MSE = " + str(mean))
    else:
        print("Kernel = " + parameters[i][0] + ", Alpha = " + str(parameters[i][1]))
        print("5-Fold Cross Validation MSE = " + str(mean))
    models.append(mean)
# Out:
# Kernel = rbf, Alpha = 1, Gamma = 0.001
# 5-Fold Cross Validation MSE = 167.94063605595335
# Kernel = poly, Alpha = 1, Gamma = 0.001
# 5-Fold Cross Validation MSE = 153.9039475963378
# Kernel = linear, Alpha = 1
# 5-Fold Cross Validation MSE = 115.30311088825911
# Kernel = rbf, Alpha = 1, Gamma = 0.01
# 5-Fold Cross Validation MSE = 110.48976004386247
# Kernel = poly, Alpha = 1, Gamma = 0.01
# 5-Fold Cross Validation MSE = 104.29374795235621
# Kernel = rbf, Alpha = 1, Gamma = 0.1
# 5-Fold Cross Validation MSE = 23.328330449259372
# Kernel = poly, Alpha = 1, Gamma = 0.1
# 5-Fold Cross Validation MSE = 17.92349045738174
# Kernel = rbf, Alpha = 1, Gamma = 1
# 5-Fold Cross Validation MSE = 17.217483065073196
# Kernel = poly, Alpha = 1, Gamma = 1
# 5-Fold Cross Validation MSE = 14.05661357413176
# Kernel = rbf, Alpha = 0.1, Gamma = 0.001
# 5-Fold Cross Validation MSE = 120.45014130018032
# Kernel = poly, Alpha = 0.1, Gamma = 0.001
# 5-Fold Cross Validation MSE = 117.10871226683648
# Kernel = linear, Alpha = 0.1
# 5-Fold Cross Validation MSE = 115.31601682043981
# Kernel = rbf, Alpha = 0.1, Gamma = 0.01
# 5-Fold Cross Validation MSE = 66.76219290757234
# Kernel = poly, Alpha = 0.1, Gamma = 0.01
# 5-Fold Cross Validation MSE = 54.26662142988446
# Kernel = rbf, Alpha = 0.1, Gamma = 0.1
# 5-Fold Cross Validation MSE = 15.803745247635977
# Kernel = poly, Alpha = 0.1, Gamma = 0.1
# 5-Fold Cross Validation MSE = 15.636494826044748
# Kernel = rbf, Alpha = 0.1, Gamma = 1
# 5-Fold Cross Validation MSE = 12.437057319349066
# Kernel = poly, Alpha = 0.1, Gamma = 1
# 5-Fold Cross Validation MSE = 15.113223476435707
# Kernel = rbf, Alpha = 0.01, Gamma = 0.001
# 5-Fold Cross Validation MSE = 106.44126039488913
# Kernel = poly, Alpha = 0.01, Gamma = 0.001
# 5-Fold Cross Validation MSE = 103.20805924382839
# Kernel = linear, Alpha = 0.01
# 5-Fold Cross Validation MSE = 115.3182212725942
# Kernel = rbf, Alpha = 0.01, Gamma = 0.01
# 5-Fold Cross Validation MSE = 22.909190826472894
# Kernel = poly, Alpha = 0.01, Gamma = 0.01
# 5-Fold Cross Validation MSE = 20.055093712027677
# Kernel = rbf, Alpha = 0.01, Gamma = 0.1
# 5-Fold Cross Validation MSE = 13.490821483626268
# Kernel = poly, Alpha = 0.01, Gamma = 0.1
# 5-Fold Cross Validation MSE = 14.068255378036792
# Kernel = rbf, Alpha = 0.01, Gamma = 1
# 5-Fold Cross Validation MSE = 11.77163318423205
# Kernel = poly, Alpha = 0.01, Gamma = 1
# 5-Fold Cross Validation MSE = 16.96489832160881
# Kernel = rbf, Alpha = 0.001, Gamma = 0.001
# 5-Fold Cross Validation MSE = 68.07390480260698
# Kernel = poly, Alpha = 0.001, Gamma = 0.001
# 5-Fold Cross Validation MSE = 56.89886953994985
# Kernel = linear, Alpha = 0.001
# 5-Fold Cross Validation MSE = 115.31845125329141
# Kernel = rbf, Alpha = 0.001, Gamma = 0.01
# 5-Fold Cross Validation MSE = 17.08444185288552
# Kernel = poly, Alpha = 0.001, Gamma = 0.01
# 5-Fold Cross Validation MSE = 17.0140267211929
# Kernel = rbf, Alpha = 0.001, Gamma = 0.1
# 5-Fold Cross Validation MSE = 13.171271890976206
# Kernel = poly, Alpha = 0.001, Gamma = 0.1
# 5-Fold Cross Validation MSE = 14.032369297791998
# Kernel = rbf, Alpha = 0.001, Gamma = 1
# 5-Fold Cross Validation MSE = 13.949153710946598
# Kernel = poly, Alpha = 0.001, Gamma = 1
# 5-Fold Cross Validation MSE = 19.925397577283793
# Kernel = rbf, Alpha = 0.005, Gamma = 0.001
# 5-Fold Cross Validation MSE = 100.04400751813274
# Kernel = poly, Alpha = 0.005, Gamma = 0.001
# 5-Fold Cross Validation MSE = 94.44575166502777
# Kernel = linear, Alpha = 0.005
# 5-Fold Cross Validation MSE = 115.31834882536683
# Kernel = rbf, Alpha = 0.005, Gamma = 0.01
# 5-Fold Cross Validation MSE = 19.33782667906926
# Kernel = poly, Alpha = 0.005, Gamma = 0.01
# 5-Fold Cross Validation MSE = 18.14009627877251
# Kernel = rbf, Alpha = 0.005, Gamma = 0.1
# 5-Fold Cross Validation MSE = 13.248322570260365
# Kernel = poly, Alpha = 0.005, Gamma = 0.1
# 5-Fold Cross Validation MSE = 13.900793403250484
# Kernel = rbf, Alpha = 0.005, Gamma = 1
# 5-Fold Cross Validation MSE = 12.03896020535995
# Kernel = poly, Alpha = 0.005, Gamma = 1
# 5-Fold Cross Validation MSE = 17.660878847368195

# %%
for i in range(len(parameters)):
    kernel = KernelRidge(kernel=parameters[i][0],alpha=parameters[i][1],gamma=parameters[i][2])
    accuracy = []
    #K-Fold Cross Validation
    #Fit model on each fold
    kernel.fit(train_x_new, train_y_new)
    #Predict on testing fold
    predict = kernel.predict(train_x_new)
    predict = predict.reshape(len(predict),1)
    #Accuracy between prediction and true value for each K-Fold Validation
    accuracy.append(compute_MSE(train_y_new, predict))
    mean = np.average(accuracy)
    if(parameters[i][0] == 'rbf'):
        print("Kernel = " + parameters[i][0] + ", Alpha = " + str(parameters[i][1]) + ", Gamma = " + str(parameters[i][2]))
        print("5-Fold Cross Validation MSE = " + str(mean))
    elif(parameters[i][0] == 'poly'):
        print("Kernel = " + parameters[i][0] + ", Alpha = " + str(parameters[i][1]) + ", Gamma = " + str(parameters[i][2]))
        print("5-Fold Cross Validation MSE = " + str(mean))
    else:
        print("Kernel = " + parameters[i][0] + ", Alpha = " + str(parameters[i][1]))
        print("5-Fold Cross Validation MSE = " + str(mean))
    models.append(mean)
# Out:
# Kernel = rbf, Alpha = 1, Gamma = 0.001
# 5-Fold Cross Validation MSE = 246.5364434726741
# Kernel = poly, Alpha = 1, Gamma = 0.001
# 5-Fold Cross Validation MSE = 223.18596477959247
# Kernel = linear, Alpha = 1
# 5-Fold Cross Validation MSE = 114.99455655963085
# Kernel = rbf, Alpha = 1, Gamma = 0.01
# 5-Fold Cross Validation MSE = 141.0458035686404
# Kernel = poly, Alpha = 1, Gamma = 0.01
# 5-Fold Cross Validation MSE = 129.74005570783518
# Kernel = rbf, Alpha = 1, Gamma = 0.1
# 5-Fold Cross Validation MSE = 40.37679417018777
# Kernel = poly, Alpha = 1, Gamma = 0.1
# 5-Fold Cross Validation MSE = 20.23442518226737
# Kernel = rbf, Alpha = 1, Gamma = 1
# 5-Fold Cross Validation MSE = 14.836377968195007
# Kernel = poly, Alpha = 1, Gamma = 1
# 5-Fold Cross Validation MSE = 4.869840310434309
# Kernel = rbf, Alpha = 0.1, Gamma = 0.001
# 5-Fold Cross Validation MSE = 146.78554549311193
# Kernel = poly, Alpha = 0.1, Gamma = 0.001
# 5-Fold Cross Validation MSE = 137.51491384073248
# Kernel = linear, Alpha = 0.1
# 5-Fold Cross Validation MSE = 114.82938850741583
# Kernel = rbf, Alpha = 0.1, Gamma = 0.01
# 5-Fold Cross Validation MSE = 97.2104059240035
# Kernel = poly, Alpha = 0.1, Gamma = 0.01
# 5-Fold Cross Validation MSE = 89.18783751030912
# Kernel = rbf, Alpha = 0.1, Gamma = 0.1
# 5-Fold Cross Validation MSE = 11.169309286125864
# Kernel = poly, Alpha = 0.1, Gamma = 0.1
# 5-Fold Cross Validation MSE = 8.93076794819264
# Kernel = rbf, Alpha = 0.1, Gamma = 1
# 5-Fold Cross Validation MSE = 3.0201246535204285
# Kernel = poly, Alpha = 0.1, Gamma = 1
# 5-Fold Cross Validation MSE = 3.802450403967504
# Kernel = rbf, Alpha = 0.01, Gamma = 0.001
# 5-Fold Cross Validation MSE = 114.64272175615896
# Kernel = poly, Alpha = 0.01, Gamma = 0.001
# 5-Fold Cross Validation MSE = 112.36375817505954
# Kernel = linear, Alpha = 0.01
# 5-Fold Cross Validation MSE = 114.82746313009663
# Kernel = rbf, Alpha = 0.01, Gamma = 0.01
# 5-Fold Cross Validation MSE = 41.46242895781609
# Kernel = poly, Alpha = 0.01, Gamma = 0.01
# 5-Fold Cross Validation MSE = 30.004013153342942
# Kernel = rbf, Alpha = 0.01, Gamma = 0.1
# 5-Fold Cross Validation MSE = 6.688967152946844
# Kernel = poly, Alpha = 0.01, Gamma = 0.1
# 5-Fold Cross Validation MSE = 6.764077776840614
# Kernel = rbf, Alpha = 0.01, Gamma = 1
# 5-Fold Cross Validation MSE = 1.0513335797391916
# Kernel = poly, Alpha = 0.01, Gamma = 1
# 5-Fold Cross Validation MSE = 3.043907226739866
# Kernel = rbf, Alpha = 0.001, Gamma = 0.001
# 5-Fold Cross Validation MSE = 97.50941906506904
# Kernel = poly, Alpha = 0.001, Gamma = 0.001
# 5-Fold Cross Validation MSE = 91.10318485638675
# Kernel = linear, Alpha = 0.001
# 5-Fold Cross Validation MSE = 114.82744356392725
# Kernel = rbf, Alpha = 0.001, Gamma = 0.01
# 5-Fold Cross Validation MSE = 11.368007333599609
# Kernel = poly, Alpha = 0.001, Gamma = 0.01
# 5-Fold Cross Validation MSE = 10.139117153756494
# Kernel = rbf, Alpha = 0.001, Gamma = 0.1
# 5-Fold Cross Validation MSE = 4.35754422729678
# Kernel = poly, Alpha = 0.001, Gamma = 0.1
# 5-Fold Cross Validation MSE = 4.744146110622073
# Kernel = rbf, Alpha = 0.001, Gamma = 1
# 5-Fold Cross Validation MSE = 0.3668094891482856
# Kernel = poly, Alpha = 0.001, Gamma = 1
# 5-Fold Cross Validation MSE = 2.571367213356879
# Kernel = rbf, Alpha = 0.005, Gamma = 0.001
# 5-Fold Cross Validation MSE = 110.66790541354942
# Kernel = poly, Alpha = 0.005, Gamma = 0.001
# 5-Fold Cross Validation MSE = 108.55829794604156
# Kernel = linear, Alpha = 0.005
# 5-Fold Cross Validation MSE = 114.82744831132378
# Kernel = rbf, Alpha = 0.005, Gamma = 0.01
# 5-Fold Cross Validation MSE = 26.148791560956443
# Kernel = poly, Alpha = 0.005, Gamma = 0.01
# 5-Fold Cross Validation MSE = 18.906662099077337
# Kernel = rbf, Alpha = 0.005, Gamma = 0.1
# 5-Fold Cross Validation MSE = 5.820401721852849
# Kernel = poly, Alpha = 0.005, Gamma = 0.1
# 5-Fold Cross Validation MSE = 6.054519600612881
# Kernel = rbf, Alpha = 0.005, Gamma = 1
# 5-Fold Cross Validation MSE = 0.7578740275141506
# Kernel = poly, Alpha = 0.005, Gamma = 1
# 5-Fold Cross Validation MSE = 2.8644428292245543

# %%
print(np.amin(models))
mini = np.argmin(models)
# Out:
# 0.3668094891482856

# %%
print(parameters[mini])
# Out:
# ['rbf', 0.001, 1]

# %%
final = KernelRidge(kernel='rbf',alpha=0.005,gamma=1)

# %%
final.fit(train_x_new, train_y_new)
# Out:
# KernelRidge(alpha=0.005, coef0=1, degree=3, gamma=1, kernel='rbf',
#             kernel_params=None)

# %%
y_1 = final.predict(train_x_new)
y_1 = y_1.reshape(len(y_1),1)

# %%
print(y_1)
# Out:
# [[91.21262776]
#  [88.11622451]
#  [80.39393544]
#  ...
#  [90.5598415 ]
#  [92.38157397]
#  [86.21256182]]

# %%
compute_MSE(train_y_new, y_1)
# Out:
# 0.7578740275141506

# %%
def kaggleize(predictions,file,float_flag):

	if(len(predictions.shape)==1):
		predictions.shape = [predictions.shape[0],1]

	ids = 1 + np.arange(predictions.shape[0])[None].T
	if float_flag:
		kaggle_predictions = np.hstack((ids,predictions)).astype(float)
	else:
		kaggle_predictions = np.hstack((ids,predictions)).astype(int)

	writer = csv.writer(open(file, 'w'))
	if predictions.shape[1] == 1:
		writer.writerow(['# id','Prediction'])
	elif predictions.shape[1] == 2:
		writer.writerow(['# id','Prediction1', 'Prediction2'])
	writer.writerows(kaggle_predictions)

# %%
kaggleize(final.predict(test_x),'submission.csv',True)
