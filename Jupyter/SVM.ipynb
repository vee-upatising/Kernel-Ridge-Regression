# %%
import numpy as np
import kaggle
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.svm import SVC

# %%
################################################################
# load corona data
def load_corona_data():
	train_x = np.load('../../Data/Corona/train_x.npy')
	train_y = np.load('../../Data/Corona/train_y.npy')
	test_x = np.load('../../Data/Corona/test_x.npy')
	return train_x, train_y, test_x
################################################################

# %%
train_x, train_y, test_x = load_corona_data()

# %%
kf = KFold(n_splits=5,shuffle=True, random_state=69)
models = []
rows = []

# %%
svm_1 = SVC(C=0.5, gamma=1,kernel='rbf')

# %%
accuracy = []
#K-Fold Cross Validation
for train_index, test_index in kf.split(train_x):
    x_train, x_test = train_x[train_index], train_x[test_index]
    y_train, y_test = train_y[train_index], train_y[test_index]
    #Fit model on each fold
    svm_1.fit(x_train, y_train)
    #Predict on testing fold
    predict = svm_1.predict(x_test)
    predict = predict.reshape(len(predict),1)
    #Accuracy between prediction and true value for each K-Fold Validation
    accuracy.append(accuracy_score(y_test, predict))

# %%
mean = np.average(accuracy)
models.append(mean)
print(mean)
# Out:
# 0.6875816993464052

# %%
svm_2 = SVC(C=0.5, gamma=1,kernel='poly',degree=3)

# %%
accuracy = []
#K-Fold Cross Validation
for train_index, test_index in kf.split(train_x):
    x_train, x_test = train_x[train_index], train_x[test_index]
    y_train, y_test = train_y[train_index], train_y[test_index]
    #Fit model on each fold
    svm_2.fit(x_train, y_train)
    #Predict on testing fold
    predict = svm_2.predict(x_test)
    predict = predict.reshape(len(predict),1)
    #Accuracy between prediction and true value for each K-Fold Validation
    accuracy.append(accuracy_score(y_test, predict))

# %%
mean = np.average(accuracy)
models.append(mean)
print(mean)
# Out:
# 0.6509803921568628

# %%
svm_3 = SVC(C=0.5, gamma=1,kernel='poly',degree=5)

# %%
accuracy = []
#K-Fold Cross Validation
for train_index, test_index in kf.split(train_x):
    x_train, x_test = train_x[train_index], train_x[test_index]
    y_train, y_test = train_y[train_index], train_y[test_index]
    #Fit model on each fold
    svm_3.fit(x_train, y_train)
    #Predict on testing fold
    predict = svm_3.predict(x_test)
    predict = predict.reshape(len(predict),1)
    #Accuracy between prediction and true value for each K-Fold Validation
    accuracy.append(accuracy_score(y_test, predict))

# %%
mean = np.average(accuracy)
models.append(mean)
print(mean)
# Out:
# 0.677124183006536

# %%
svm_4 = SVC(C=0.5,kernel='linear')

# %%
accuracy = []
#K-Fold Cross Validation
for train_index, test_index in kf.split(train_x):
    x_train, x_test = train_x[train_index], train_x[test_index]
    y_train, y_test = train_y[train_index], train_y[test_index]
    #Fit model on each fold
    svm_4.fit(x_train, y_train)
    #Predict on testing fold
    predict = svm_4.predict(x_test)
    predict = predict.reshape(len(predict),1)
    #Accuracy between prediction and true value for each K-Fold Validation
    accuracy.append(accuracy_score(y_test, predict))

# %%
mean = np.average(accuracy)
models.append(mean)
print(mean)
# Out:
# 0.7516339869281046

# %%
rows.append(models)
models = []
print(rows)
# Out:
# [[0.6875816993464052, 0.6509803921568628, 0.677124183006536, 0.7516339869281046]]

# %%
svm_5 = SVC(C=0.5, gamma=0.01,kernel='rbf')

# %%
accuracy = []
#K-Fold Cross Validation
for train_index, test_index in kf.split(train_x):
    x_train, x_test = train_x[train_index], train_x[test_index]
    y_train, y_test = train_y[train_index], train_y[test_index]
    #Fit model on each fold
    svm_5.fit(x_train, y_train)
    #Predict on testing fold
    predict = svm_5.predict(x_test)
    predict = predict.reshape(len(predict),1)
    #Accuracy between prediction and true value for each K-Fold Validation
    accuracy.append(accuracy_score(y_test, predict))

# %%
mean = np.average(accuracy)
models.append(mean)
print(mean)
# Out:
# 0.6954248366013072

# %%
svm_6 = SVC(C=0.5, gamma=0.01,kernel='poly',degree=3)

# %%
accuracy = []
#K-Fold Cross Validation
for train_index, test_index in kf.split(train_x):
    x_train, x_test = train_x[train_index], train_x[test_index]
    y_train, y_test = train_y[train_index], train_y[test_index]
    #Fit model on each fold
    svm_6.fit(x_train, y_train)
    #Predict on testing fold
    predict = svm_6.predict(x_test)
    predict = predict.reshape(len(predict),1)
    #Accuracy between prediction and true value for each K-Fold Validation
    accuracy.append(accuracy_score(y_test, predict))

# %%
mean = np.average(accuracy)
models.append(mean)
print(mean)
# Out:
# 0.6875816993464052

# %%
svm_7 = SVC(C=0.5, gamma=0.01,kernel='poly',degree=5)

# %%
accuracy = []
#K-Fold Cross Validation
for train_index, test_index in kf.split(train_x):
    x_train, x_test = train_x[train_index], train_x[test_index]
    y_train, y_test = train_y[train_index], train_y[test_index]
    #Fit model on each fold
    svm_7.fit(x_train, y_train)
    #Predict on testing fold
    predict = svm_7.predict(x_test)
    predict = predict.reshape(len(predict),1)
    #Accuracy between prediction and true value for each K-Fold Validation
    accuracy.append(accuracy_score(y_test, predict))

# %%
mean = np.average(accuracy)
models.append(mean)
print(mean)
# Out:
# 0.6875816993464052

# %%
rows.append(models)
models = []
print(rows)
# Out:
# [[0.6875816993464052, 0.6509803921568628, 0.677124183006536, 0.7516339869281046], [0.6954248366013072, 0.6875816993464052, 0.6875816993464052]]

# %%
svm_8 = SVC(C=0.5, gamma=0.001,kernel='rbf')

# %%
accuracy = []
#K-Fold Cross Validation
for train_index, test_index in kf.split(train_x):
    x_train, x_test = train_x[train_index], train_x[test_index]
    y_train, y_test = train_y[train_index], train_y[test_index]
    #Fit model on each fold
    svm_8.fit(x_train, y_train)
    #Predict on testing fold
    predict = svm_8.predict(x_test)
    predict = predict.reshape(len(predict),1)
    #Accuracy between prediction and true value for each K-Fold Validation
    accuracy.append(accuracy_score(y_test, predict))

# %%
mean = np.average(accuracy)
models.append(mean)
print(mean)
# Out:
# 0.6875816993464052

# %%
svm_9 = SVC(C=0.5, gamma=0.001,kernel='poly',degree=3)

# %%
accuracy = []
#K-Fold Cross Validation
for train_index, test_index in kf.split(train_x):
    x_train, x_test = train_x[train_index], train_x[test_index]
    y_train, y_test = train_y[train_index], train_y[test_index]
    #Fit model on each fold
    svm_9.fit(x_train, y_train)
    #Predict on testing fold
    predict = svm_9.predict(x_test)
    predict = predict.reshape(len(predict),1)
    #Accuracy between prediction and true value for each K-Fold Validation
    accuracy.append(accuracy_score(y_test, predict))

# %%
mean = np.average(accuracy)
models.append(mean)
print(mean)
# Out:
# 0.6875816993464052

# %%
svm_10 = SVC(C=0.5, gamma=0.001,kernel='poly',degree=5)

# %%
accuracy = []
#K-Fold Cross Validation
for train_index, test_index in kf.split(train_x):
    x_train, x_test = train_x[train_index], train_x[test_index]
    y_train, y_test = train_y[train_index], train_y[test_index]
    #Fit model on each fold
    svm_10.fit(x_train, y_train)
    #Predict on testing fold
    predict = svm_10.predict(x_test)
    predict = predict.reshape(len(predict),1)
    #Accuracy between prediction and true value for each K-Fold Validation
    accuracy.append(accuracy_score(y_test, predict))

# %%
mean = np.average(accuracy)
models.append(mean)
print(mean)
# Out:
# 0.6875816993464052

# %%
rows.append(models)
models = []
print(rows)
# Out:
# [[0.6875816993464052, 0.6509803921568628, 0.677124183006536, 0.7516339869281046], [0.6954248366013072, 0.6875816993464052, 0.6875816993464052], [0.6875816993464052, 0.6875816993464052, 0.6875816993464052]]

# %%
svm_11 = SVC(C=0.05, gamma=1,kernel='rbf')

# %%
accuracy = []
#K-Fold Cross Validation
for train_index, test_index in kf.split(train_x):
    x_train, x_test = train_x[train_index], train_x[test_index]
    y_train, y_test = train_y[train_index], train_y[test_index]
    #Fit model on each fold
    svm_11.fit(x_train, y_train)
    #Predict on testing fold
    predict = svm_11.predict(x_test)
    predict = predict.reshape(len(predict),1)
    #Accuracy between prediction and true value for each K-Fold Validation
    accuracy.append(accuracy_score(y_test, predict))

# %%
mean = np.average(accuracy)
models.append(mean)
print(mean)
# Out:
# 0.6875816993464052

# %%
svm_12 = SVC(C=0.05, gamma=1,kernel='poly',degree=3)

# %%
accuracy = []
#K-Fold Cross Validation
for train_index, test_index in kf.split(train_x):
    x_train, x_test = train_x[train_index], train_x[test_index]
    y_train, y_test = train_y[train_index], train_y[test_index]
    #Fit model on each fold
    svm_12.fit(x_train, y_train)
    #Predict on testing fold
    predict = svm_12.predict(x_test)
    predict = predict.reshape(len(predict),1)
    #Accuracy between prediction and true value for each K-Fold Validation
    accuracy.append(accuracy_score(y_test, predict))

# %%
mean = np.average(accuracy)
models.append(mean)
print(mean)
# Out:
# 0.6496732026143791

# %%
svm_13 = SVC(C=0.05, gamma=1,kernel='poly',degree=5)

# %%
accuracy = []
#K-Fold Cross Validation
for train_index, test_index in kf.split(train_x):
    x_train, x_test = train_x[train_index], train_x[test_index]
    y_train, y_test = train_y[train_index], train_y[test_index]
    #Fit model on each fold
    svm_13.fit(x_train, y_train)
    #Predict on testing fold
    predict = svm_13.predict(x_test)
    predict = predict.reshape(len(predict),1)
    #Accuracy between prediction and true value for each K-Fold Validation
    accuracy.append(accuracy_score(y_test, predict))

# %%
mean = np.average(accuracy)
models.append(mean)
print(mean)
# Out:
# 0.677124183006536

# %%
svm_14 = SVC(C=0.05,kernel='linear')

# %%
accuracy = []
#K-Fold Cross Validation
for train_index, test_index in kf.split(train_x):
    x_train, x_test = train_x[train_index], train_x[test_index]
    y_train, y_test = train_y[train_index], train_y[test_index]
    #Fit model on each fold
    svm_14.fit(x_train, y_train)
    #Predict on testing fold
    predict = svm_14.predict(x_test)
    predict = predict.reshape(len(predict),1)
    #Accuracy between prediction and true value for each K-Fold Validation
    accuracy.append(accuracy_score(y_test, predict))

# %%
mean = np.average(accuracy)
models.append(mean)
print(mean)
# Out:
# 0.7542483660130719

# %%
rows.append(models)
models = []
print(rows)
# Out:
# [[0.6875816993464052, 0.6509803921568628, 0.677124183006536, 0.7516339869281046], [0.6954248366013072, 0.6875816993464052, 0.6875816993464052], [0.6875816993464052, 0.6875816993464052, 0.6875816993464052], [0.6875816993464052, 0.6496732026143791, 0.677124183006536, 0.7542483660130719]]

# %%
parameters = [['rbf',0.5,1,1],['poly',0.5,1,3],['poly',0.5,1,5],['linear',0.5,1,1]]

# %%
for i in range(len(parameters)):
    svm = SVC(kernel=parameters[i][0],C=parameters[i][1],gamma=parameters[i][2],degree=parameters[i][3])
    accuracy = []
    #K-Fold Cross Validation
    for train_index, test_index in kf.split(train_x):
        x_train, x_test = train_x[train_index], train_x[test_index]
        y_train, y_test = train_y[train_index], train_y[test_index]
        #Fit model on each fold
        svm.fit(x_train, y_train)
        #Predict on testing fold
        predict = svm.predict(x_test)
        predict = predict.reshape(len(predict),1)
        #Accuracy between prediction and true value for each K-Fold Validation
        accuracy.append(accuracy_score(y_test, predict))
    mean = np.average(accuracy)
    models.append(mean)
